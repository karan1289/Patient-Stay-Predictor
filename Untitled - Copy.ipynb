# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
data=pd.read_csv(r'C:\Users\user\Music\Projects\AnalyticsVidhya\train.csv')
test_data=pd.read_csv(r'C:\Users\user\Music\Projects\AnalyticsVidhya\test.csv')

# %%
test_data.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318439             21                  c                   3
# 1   318440             29                  a                   4
# 2   318441             26                  b                   2
# 3   318442              6                  a                   6
# 4   318443             28                  b                  11
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Z                                  3  gynecology
# 1                    X                                  2  gynecology
# 2                    Y                                  3  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  2  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  A        2.0      17006                2.0
# 1         S                  F        2.0      17006                2.0
# 2         Q                  D        4.0      17006                2.0
# 3         Q                  F        2.0      17006                2.0
# 4         R                  F        2.0      17006                2.0
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      2  71-80
# 1            Trauma            Moderate                      4  71-80
# 2         Emergency            Moderate                      3  71-80
# 3            Trauma            Moderate                      3  71-80
# 4            Trauma            Moderate                      4  71-80
#
#    Admission_Deposit
# 0             3095.0
# 1             4018.0
# 2             4492.0
# 3             4173.0
# 4             4161.0

# %%
plt.figure(figsize=(15,5))
sns.countplot(test_data['City_Code_Patient'])

# %%
test_data['City_Code_Patient']=test_data['City_Code_Patient'].fillna(8.0)

# %%
test_data.isna().sum()
# Out:
# case_id                               0
# Hospital_code                         0
# Hospital_type_code                    0
# City_Code_Hospital                    0
# Hospital_region_code                  0
# Available Extra Rooms in Hospital     0
# Department                            0
# Ward_Type                             0
# Ward_Facility_Code                    0
# Bed Grade                            35
# patientid                             0
# City_Code_Patient                     0
# Type of Admission                     0
# Severity of Illness                   0
# Visitors with Patient                 0
# Age                                   0
# Admission_Deposit                     0
# dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['City_Code_Patient'])

# %%
data['City_Code_Patient']=data['City_Code_Patient'].fillna(8.0)

# %%
data.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 318433   318434              6                  a                   6
# 318434   318435             24                  a                   1
# 318435   318436              7                  a                   4
# 318436   318437             11                  b                   2
# 318437   318438             19                  a                   7
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 318433                    X                                  3  radiotherapy
# 318434                    X                                  2    anesthesia
# 318435                    X                                  3    gynecology
# 318436                    Y                                  3    anesthesia
# 318437                    Y                                  5    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 318433         Q                  F        4.0      86499               23.0
# 318434         Q                  E        4.0        325                8.0
# 318435         R                  F        4.0     125235               10.0
# 318436         Q                  D        3.0      91081                8.0
# 318437         Q                  C        2.0      21641                8.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 318433         Emergency            Moderate                      3  41-50
# 318434            Urgent            Moderate                      4  81-90
# 318435         Emergency               Minor                      3  71-80
# 318436            Trauma               Minor                      5  11-20
# 318437         Emergency               Minor                      2  11-20
#
#         Admission_Deposit   Stay
# 318433             4144.0  11-20
# 318434             6699.0  31-40
# 318435             4235.0  11-20
# 318436             3761.0  11-20
# 318437             4752.0   0-10

# %%
data['Bed Grade'].value_counts()
# Out:
# 2.0    123671
# 3.0    110583
# 4.0     57566
# 1.0     26505
# Name: Bed Grade, dtype: int64

# %%
data1=data.drop(['City_Code_Hospital','Hospital_region_code','patientid'],axis=1)
test_data1=test_data.drop(['City_Code_Hospital','Hospital_region_code','patientid'],axis=1)

# %%
data1.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  \
# 0        1              8                  c
# 1        2              2                  c
# 2        3             10                  e
# 3        4             26                  b
# 4        5             26                  b
#
#    Available Extra Rooms in Hospital    Department Ward_Type  \
# 0                                  3  radiotherapy         R
# 1                                  2  radiotherapy         S
# 2                                  2    anesthesia         S
# 3                                  2  radiotherapy         R
# 4                                  2  radiotherapy         S
#
#   Ward_Facility_Code  Bed Grade  City_Code_Patient Type of Admission  \
# 0                  F        2.0                7.0         Emergency
# 1                  F        2.0                7.0            Trauma
# 2                  E        2.0                7.0            Trauma
# 3                  D        2.0                7.0            Trauma
# 4                  D        2.0                7.0            Trauma
#
#   Severity of Illness  Visitors with Patient    Age  Admission_Deposit   Stay
# 0             Extreme                      2  51-60             4911.0   0-10
# 1             Extreme                      2  51-60             5954.0  41-50
# 2             Extreme                      2  51-60             4745.0  31-40
# 3             Extreme                      2  51-60             7272.0  41-50
# 4             Extreme                      2  51-60             5558.0  41-50

# %%
from sklearn.preprocessing import LabelEncoder
le_hc=LabelEncoder()

# %%
data1['Hospital_code']=le_hc.fit_transform(data1['Hospital_code'])
test_data1['Hospital_code']=le_hc.transform(test_data1['Hospital_code'])

# %%
le_ht=LabelEncoder()
data1['Hospital_type_code']=le_ht.fit_transform(data1['Hospital_type_code'])
test_data1['Hospital_type_code']=le_ht.transform(test_data1['Hospital_type_code'])

# %%
le_d=LabelEncoder()
data1['Department']=le_d.fit_transform(data1['Department'])
test_data1['Department']=le_d.transform(test_data1['Department'])

# %%
le_w=LabelEncoder()
data1['Ward_Type']=le_w.fit_transform(data1['Ward_Type'])
test_data1['Ward_Type']=le_w.transform(test_data1['Ward_Type'])

# %%
le_wf=LabelEncoder()
data1['Ward_Facility_Code']=le_wf.fit_transform(data1['Ward_Facility_Code'])
test_data1['Ward_Facility_Code']=le_wf.transform(test_data1['Ward_Facility_Code'])

# %%
le_p=LabelEncoder()
data1['City_Code_Patient']=le_p.fit_transform(data1['City_Code_Patient'])
test_data1['City_Code_Patient']=le_p.transform(test_data1['City_Code_Patient'])

# %%
test_data1
# Out:
#         case_id  Hospital_code  Hospital_type_code  \
# 0        318439             20                   2
# 1        318440             28                   0
# 2        318441             25                   1
# 3        318442              5                   0
# 4        318443             27                   1
# ...         ...            ...                 ...
# 137052   455491             10                   1
# 137053   455492             24                   4
# 137054   455493             29                   2
# 137055   455494              4                   0
# 137056   455495              5                   0
#
#         Available Extra Rooms in Hospital  Department  Ward_Type  \
# 0                                       3           2          3
# 1                                       2           2          3
# 2                                       3           2          1
# 3                                       3           2          1
# 4                                       2           2          2
# ...                                   ...         ...        ...
# 137052                                  4           1          1
# 137053                                  2           3          2
# 137054                                  2           1          2
# 137055                                  2           1          2
# 137056                                  3           2          1
#
#         Ward_Facility_Code  Bed Grade  City_Code_Patient Type of Admission  \
# 0                        0        2.0                  1         Emergency
# 1                        5        2.0                  1            Trauma
# 2                        3        4.0                  1         Emergency
# 3                        5        2.0                  1            Trauma
# 4                        5        2.0                  1            Trauma
# ...                    ...        ...                ...               ...
# 137052                   3        3.0                  2         Emergency
# 137053                   4        4.0                  6         Emergency
# 137054                   0        4.0                 11            Urgent
# 137055                   4        4.0                  9            Trauma
# 137056                   5        4.0                  2            Trauma
#
#        Severity of Illness  Visitors with Patient    Age  Admission_Deposit
# 0                 Moderate                      2  71-80             3095.0
# 1                 Moderate                      4  71-80             4018.0
# 2                 Moderate                      3  71-80             4492.0
# 3                 Moderate                      3  71-80             4173.0
# 4                 Moderate                      4  71-80             4161.0
# ...                    ...                    ...    ...                ...
# 137052               Minor                      4  41-50             6313.0
# 137053            Moderate                      2   0-10             3510.0
# 137054               Minor                      2   0-10             7190.0
# 137055               Minor                      2  41-50             5435.0
# 137056             Extreme                      5  51-60             4702.0
#
# [137057 rows x 14 columns]

# %%
le_a=LabelEncoder()
data1['Type of Admission']=le_a.fit_transform(data1['Type of Admission'])
test_data1['Type of Admission']=le_a.transform(test_data1['Type of Admission'])

# %%
le_ill=LabelEncoder()
data1['Severity of Illness']=le_ill.fit_transform(data1['Severity of Illness'])
test_data1['Severity of Illness']=le_ill.transform(test_data1['Severity of Illness'])

# %%
data1['Age'].value_counts()
# Out:
# 41-50     63749
# 31-40     63639
# 51-60     48514
# 21-30     40843
# 71-80     35792
# 61-70     33687
# 11-20     16768
# 81-90      7890
# 0-10       6254
# 91-100     1302
# Name: Age, dtype: int64

# %%
data1['Age']=data1['Age'].map({'0-10':1,'11-20':2,'21-30':3,'31-40':4,'41-50':5,'51-60':6,'61-70':7,'71-80':8,'81-90':9,'91-100':10})
test_data1['Age']=test_data1['Age'].map({'0-10':1,'11-20':2,'21-30':3,'31-40':4,'41-50':5,'51-60':6,'61-70':7,'71-80':8,'81-90':9,'91-100':10})

# %%
data1['Stay'].value_counts()
# Out:
# 21-30                 87491
# 11-20                 78139
# 31-40                 55159
# 51-60                 35018
# 0-10                  23604
# 41-50                 11743
# 71-80                 10254
# More than 100 Days     6683
# 81-90                  4838
# 91-100                 2765
# 61-70                  2744
# Name: Stay, dtype: int64

# %%
data1['Stay']=data1['Stay'].map({'0-10':1,'11-20':2,'21-30':3,'31-40':4,'41-50':5,'51-60':6,'61-70':7,'71-80':8,'81-90':9,'91-100':10,'More than 100 Days':11})

# %%
data1.head()
# Out:
#    case_id  Hospital_code  Hospital_type_code  \
# 0        1              7                   2
# 1        2              1                   2
# 2        3              9                   4
# 3        4             25                   1
# 4        5             25                   1
#
#    Available Extra Rooms in Hospital  Department  Ward_Type  \
# 0                                  3           3          2
# 1                                  2           3          3
# 2                                  2           1          3
# 3                                  2           3          2
# 4                                  2           3          3
#
#    Ward_Facility_Code  Bed Grade  City_Code_Patient  Type of Admission  \
# 0                   5        2.0                  6                  0
# 1                   5        2.0                  6                  1
# 2                   4        2.0                  6                  1
# 3                   3        2.0                  6                  1
# 4                   3        2.0                  6                  1
#
#    Severity of Illness  Visitors with Patient  Age  Admission_Deposit  Stay
# 0                    0                      2    6             4911.0     1
# 1                    0                      2    6             5954.0     5
# 2                    0                      2    6             4745.0     4
# 3                    0                      2    6             7272.0     5
# 4                    0                      2    6             5558.0     5

# %%
x=data1.drop('Stay',axis=1)
y=data1['Stay']

# %%
x
# Out:
#         case_id  Hospital_code  Hospital_type_code  \
# 0             1              7                   2
# 1             2              1                   2
# 2             3              9                   4
# 3             4             25                   1
# 4             5             25                   1
# ...         ...            ...                 ...
# 318433   318434              5                   0
# 318434   318435             23                   0
# 318435   318436              6                   0
# 318436   318437             10                   1
# 318437   318438             18                   0
#
#         Available Extra Rooms in Hospital  Department  Ward_Type  \
# 0                                       3           3          2
# 1                                       2           3          3
# 2                                       2           1          3
# 3                                       2           3          2
# 4                                       2           3          3
# ...                                   ...         ...        ...
# 318433                                  3           3          1
# 318434                                  2           1          1
# 318435                                  3           2          2
# 318436                                  3           1          1
# 318437                                  5           2          1
#
#         Ward_Facility_Code  Bed Grade  City_Code_Patient  Type of Admission  \
# 0                        5        2.0                  6                  0
# 1                        5        2.0                  6                  1
# 2                        4        2.0                  6                  1
# 3                        3        2.0                  6                  1
# 4                        3        2.0                  6                  1
# ...                    ...        ...                ...                ...
# 318433                   5        4.0                 21                  0
# 318434                   4        4.0                  7                  2
# 318435                   5        4.0                  9                  0
# 318436                   3        3.0                  7                  1
# 318437                   2        2.0                  7                  0
#
#         Severity of Illness  Visitors with Patient  Age  Admission_Deposit
# 0                         0                      2    6             4911.0
# 1                         0                      2    6             5954.0
# 2                         0                      2    6             4745.0
# 3                         0                      2    6             7272.0
# 4                         0                      2    6             5558.0
# ...                     ...                    ...  ...                ...
# 318433                    2                      3    5             4144.0
# 318434                    2                      4    9             6699.0
# 318435                    1                      3    8             4235.0
# 318436                    1                      5    2             3761.0
# 318437                    1                      2    2             4752.0
#
# [318438 rows x 14 columns]

# %%
x.shape
# Out:
# (318438, 14)

# %%
y.shape
# Out:
# (318438,)

# %%
sns.distplot(x['Bed Grade'])

# %%
x['Bed Grade']=x['Bed Grade'].fillna(x['Bed Grade'].median())
test_data1['Bed Grade']=test_data1['Bed Grade'].fillna(x['Bed Grade'].median())

# %%
x['Hospital_type_code'].value_counts()
# Out:
# 0    143425
# 1     68946
# 2     45928
# 4     24770
# 3     20389
# 5     10703
# 6      4277
# Name: Hospital_type_code, dtype: int64

# %%
x_test=test_data1

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### ANN

# %%
y_train
# Out:
# 305797    4
# 139943    2
# 182403    3
# 12118     2
# 66747     3
#          ..
# 122579    4
# 304137    4
# 152315    3
# 117952    4
# 305711    8
# Name: Stay, Length: 254750, dtype: int64

# %%
y_train.shape
# Out:
# (254750,)

# %%
y.shape
# Out:
# (318438,)

# %%
import tensorflow as tf

# %%
hidden_layer_size=50
output_size=11

ann=tf.keras.models.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax'),
])

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (50, 50)                  750
# _________________________________________________________________
# dense_1 (Dense)              (50, 50)                  2550
# _________________________________________________________________
# dense_2 (Dense)              (50, 50)                  2550
# _________________________________________________________________
# dense_3 (Dense)              (50, 50)                  2550
# _________________________________________________________________
# dense_4 (Dense)              (50, 50)                  2550
# _________________________________________________________________
# dense_5 (Dense)              (50, 11)                  561
# =================================================================
# Total params: 11,511
# Trainable params: 11,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
ann.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
early_stopping=tf.keras.callbacks.EarlyStopping(patience=300)

# %%
ann.fit(x_train,
        y_train,
       batch_size=50,
       epochs=100,
        validation_data=(x_val,y_val),
       callbacks=[early_stopping],verbose=2)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer dense is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-ba502fd5ab2a> in <module>
#       4        epochs=100,
#       5         validation_data=(x_val,y_val),
# ----> 6        callbacks=[early_stopping],verbose=2)
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     695     self._concrete_stateful_fn = (
#     696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 697             *args, **kwds))
#     698
#     699     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3073             arg_names=arg_names,
#    3074             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3075             capture_by_value=self._capture_by_value),
#    3076         self._function_attributes,
#    3077         function_spec=self.function_spec,
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# F:\Anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:806 train_function  *
#         return step_function(self, iterator)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     F:\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:789 run_step  **
#         outputs = model.train_step(data)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:749 train_step
#         y, y_pred, sample_weight, regularization_losses=self.losses)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     F:\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (50, 1) and (50, 11) are incompatible

# %%
pred=ann.predict(x_test)

# %%
pred

# %%
from sklearn.ensemble import RandomForestClassifier
classifier_forest=RandomForestClassifier()

# %%
classifier_forest.fit(final_data,y)

# %%
predictions=classifier_forest.predict(x_test)

# %%
predictions

# %%
pred=pd.DataFrame()

# %%
pred['prediction']=predictions

# %%
pred

# %%
pred['prediction']=pred['prediction'].map({1:'0-10',2:'11-20',3:'21-30',4:'31-40',5:'41-50',6:'51-60',7:'61-70',8:'71-80',9:'81-90',10:'91-100',11:'More than 100 Days'})

# %%
pred

# %%
index=test_data1['case_id']

# %%
pred['case_id']=index

# %%
pred.columns=['prediction','case_id']

# %%
col=pred.columns.values
col

# %%
pred=pred[['case_id','prediction']]

# %%
pred=pred.rename(columns={'prediction':'Stay'})
pred

# %%
pred.to_csv('Submission_corona.csv', index=False , header = 1)

# %%
y_test=pd.read_csv(r'C:\Users\user\Music\Projects\AnalyticsVidhya\sample_submission.csv')

# %%
y_test

# %%
from sklearn.tree import DecisionTreeClassifier
tree_class=DecisionTreeClassifier(max_leaf_nodes=70000)
tree_class.fit(final_data,y)
Y_pred_tree=tree_class.predict(x_test)

# %%
sub=pd.DataFrame()
sub['case_id']=index
sub['Stay']=Y_pred_tree
sub.to_csv('Submission_corona2.csv', index=False , header = 1)

# %%
from catboost import CatBoostClassifier
classifier_cat=CatBoostClassifier(learning_rate=0.3)

# %%
classifier_cat.fit(final_data,y)

# %%
from xgboost import XGBClassifier
classifier_xgb=XGBClassifier()
classifier_xgb.fit(final_data,y)

# %%
pred_xgb=classifier_xgb.predict(x_test)

# %%
sub1=pd.DataFrame()
sub1['case_id']=index
sub1['Stay']=pred_xgb

# %%
sub1['Stay']=sub1['Stay'].map({1:'0-10',2:'11-20',3:'21-30',4:'31-40',5:'41-50',6:'51-60',7:'61-70',8:'71-80',9:'81-90',10:'91-100',11:'More than 100 Days'})

# %%
sub1.to_csv('Submission_corona3.csv', index=False , header = 1)

# %%
sub1
